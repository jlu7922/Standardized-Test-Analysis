# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **Between the SAT and ACT, many students have a preference of one exam over the other, to play to their academic strengths. We wish to see if there is a difference in performance between the two exams for certain areas of aptitude.**

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **Other Background**
#
# Traditionally, students who excel in math and science prefer to take the ACT because of its Science section and the deeper scope of topics of its Math section. Many find that the SAT has more difficult reading comprehension sections, which might be more suitable for students who have strong humanities backgrounds, especially in critical thinking and writing.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **Datasets Used**
#
# * sat_2019.csv
#
# * act_2019.csv
#
# * sat_2019_by_intended_college_major.csv
#
# * act_2020_by_intended_college_major.csv

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# act_2020_by_intended_college_major.csv derived from:
#
# *Table 4.1. Distribution of Planned Educational Majors for All Students by College Plans*
#
# https://www.act.org/content/dam/act/unsecured/documents/2020/2020-National-ACT-Profile-Report.pdf

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def find_mean(list):
    sum = 0 
    for n in list:
        sum += n 
    return sum/len(list)

find_mean([10, 20, 40])
# Out:
# 23.333333333333332

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def find_std(list):
    n = len(list)
    u = find_mean(list)
    total = 0
    for n in range(1,n+1):
        total += (n-u)**2
    return ((1/n)*total)**(.5)

find_std([10, 20, 40])
# Out:
# 21.348952615474552

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def data_clean(string):
    cleaned_string = string.replace('%', '')
    return float(cleaned_string)/100

data_clean('30.5')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %%
# Import .csv files

act_by_major = pd.read_csv('../data/act_2020_by_intended_college_major.csv')
sat_by_major = pd.read_csv('../data/sat_2019_by_intended_college_major.csv')
act_2019 = pd.read_csv('../data/act_2019.csv')
sat_2019 = pd.read_csv('../data/sat_2019.csv')

# %%
# Displaying the data
act_by_major.head()
# Out:
#                       Planned Educational Major  Number  Percent  Avg ACT Comp
# 0  Agriculture & Natural Resources Conservation   21781        1          19.9
# 1                                  Architecture   15422        1          21.1
# 2     Area, Ethnic, & Multidisciplinary Studies    1761        0          21.6
# 3                     Arts: Visual & Performing   67693        4          20.7
# 4                                      Business  125457        8          21.5

# %%
sat_by_major.head()
# Out:
#                                 IntendedCollegeMajor TestTakers Percent  \
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                  Architecture and Related Services     28,988      2%
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 3                 Biological and Biomedical Sciences    155,834      8%
# 4  Business, Management, Marketing, and Related S...    221,523     12%
#
#    Total  ReadingWriting  Math
# 0    977             496   481
# 1   1047             520   527
# 2   1040             536   504
# 3   1139             572   566
# 4   1072             534   537

# %%
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
# Dropping unused columns, for individual SAT section scores

sat_by_major.drop(columns = ['ReadingWriting', 'Math'], inplace = True)
sat_by_major.head()
# Out:
#                                 IntendedCollegeMajor TestTakers Percent  Total
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1%    977
# 1                  Architecture and Related Services     28,988      2%   1047
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0%   1040
# 3                 Biological and Biomedical Sciences    155,834      8%   1139
# 4  Business, Management, Marketing, and Related S...    221,523     12%   1072

# %%
sat_2019.drop(columns = ['EBRW', 'Math'], inplace = True)
sat_2019.head()
# Out:
#         State Participation Rate  Total
# 0     Alabama                 7%   1143
# 1      Alaska                41%   1097
# 2     Arizona                31%   1134
# 3    Arkansas                 6%   1141
# 4  California                63%   1065

# %%
# Check for missing values
act_by_major.isnull().sum()
# Out:
# Planned Educational Major    0
# Number                       0
# Percent                      0
# Avg ACT Comp                 0
# dtype: int64

# %%
sat_by_major.isnull().sum()
# Out:
# IntendedCollegeMajor    0
# TestTakers              0
# Percent                 0
# Total                   0
# dtype: int64

# %%
act_2019.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
sat_2019.isnull().sum()
# Out:
# State                 0
# Participation Rate    0
# Total                 0
# dtype: int64

# %%
# Display the data types of each feature
act_by_major.dtypes
# Out:
# Planned Educational Major     object
# Number                         int64
# Percent                        int64
# Avg ACT Comp                 float64
# dtype: object

# %%
sat_by_major.dtypes
# Out:
# IntendedCollegeMajor    object
# TestTakers              object
# Percent                 object
# Total                    int64
# dtype: object

# %%
act_2019.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
sat_2019.dtypes
# Out:
# State                 object
# Participation Rate    object
# Total                  int64
# dtype: object

# %%
# Fix any incorrect data types

sat_by_major.head()
# Out:
#                                 IntendedCollegeMajor TestTakers Percent  Total
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1%    977
# 1                  Architecture and Related Services     28,988      2%   1047
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0%   1040
# 3                 Biological and Biomedical Sciences    155,834      8%   1139
# 4  Business, Management, Marketing, and Related S...    221,523     12%   1072

# %%
# First, let's get rid of % symbols and commas

sat_by_major['Percent'] = sat_by_major['Percent'].astype('string')
sat_by_major['Percent'] = sat_by_major['Percent'].map(data_clean)
sat_by_major['Percent'] = sat_by_major['Percent'].astype('float')



sat_by_major['TestTakers'] = sat_by_major['TestTakers'].str.replace(',', '')
sat_by_major['TestTakers'] = sat_by_major['TestTakers'].astype('float')

sat_by_major.head()
# Out:
#                                 IntendedCollegeMajor  TestTakers  Percent  \
# 0  Agriculture, AgricultureOperations, and Relate...     24913.0     0.01
# 1                  Architecture and Related Services     28988.0     0.02
# 2         Area, Ethnic, Cultural, and Gender Studies      2629.0     0.00
# 3                 Biological and Biomedical Sciences    155834.0     0.08
# 4  Business, Management, Marketing, and Related S...    221523.0     0.12
#
#    Total
# 0    977
# 1   1047
# 2   1040
# 3   1139
# 4   1072

# %%
# Getting rid of %

act_by_major['Percent'] = act_by_major['Percent'].astype('string')
act_by_major['Percent'] = act_by_major['Percent'].map(data_clean)
act_by_major['Percent'] = act_by_major['Percent'].astype('float')

# %%
act_by_major.head()
# Out:
#                       Planned Educational Major  Number  Percent  Avg ACT Comp
# 0  Agriculture & Natural Resources Conservation   21781     0.01          19.9
# 1                                  Architecture   15422     0.01          21.1
# 2     Area, Ethnic, & Multidisciplinary Studies    1761     0.00          21.6
# 3                     Arts: Visual & Performing   67693     0.04          20.7
# 4                                      Business  125457     0.08          21.5

# %%
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
# Getting rid of %

act_2019['Participation'] = act_2019['Participation'].astype('string')
act_2019['Participation'] = act_2019['Participation'].map(data_clean)
act_2019['Participation'] = act_2019['Participation'].astype('float')

act_2019.head()
# Out:
#         State  Participation  Composite
# 0     Alabama           1.00       18.9
# 1      Alaska           0.38       20.1
# 2     Arizona           0.73       19.0
# 3    Arkansas           1.00       19.3
# 4  California           0.23       22.6

# %%
sat_2019.head()
# Out:
#         State Participation Rate  Total
# 0     Alabama                 7%   1143
# 1      Alaska                41%   1097
# 2     Arizona                31%   1134
# 3    Arkansas                 6%   1141
# 4  California                63%   1065

# %%
sat_2019['Participation Rate'].value_counts()
# Out:
# 100%    8
# 3%      6
# 4%      5
# 68%     3
# 66%     2
# —       2
# 70%     2
# 51%     2
# 99%     2
# 7%      2
# 82%     2
# 71%     1
# 31%     1
# 6%      1
# 22%     1
# 19%     1
# 2%      1
# 63%     1
# 79%     1
# 54%     1
# 95%     1
# 20%     1
# 9%      1
# 81%     1
# 41%     1
# 94%     1
# 5%      1
# 18%     1
# Name: Participation Rate, dtype: int64

# %%
# Before we get rid of the % symbols, we need to get rid of the '—' values by making them NaN

sat_2019['Participation Rate'] = sat_2019['Participation Rate'].map(lambda participation: np.nan if participation == '—' else participation)
sat_2019.dropna(inplace = True)

sat_2019['Participation Rate'] = sat_2019['Participation Rate'].astype('string')
sat_2019['Participation Rate'] = sat_2019['Participation Rate'].map(data_clean)
sat_2019['Participation Rate'] = sat_2019['Participation Rate'].astype('float')

sat_2019.head()
# Out:
#         State  Participation Rate  Total
# 0     Alabama                0.07   1143
# 1      Alaska                0.41   1097
# 2     Arizona                0.31   1134
# 3    Arkansas                0.06   1141
# 4  California                0.63   1065

# %%
# Renaming columns to match between datasets

act_by_major.rename(columns = {'Planned Educational Major' : 'Intended Major', 
                               'Number' : 'Number of Students',
                               'Avg ACT Comp' : 'Avg ACT Score'}, inplace=True)

# %%
sat_by_major.rename(columns = {'IntendedCollegeMajor' : 'Intended Major',
                               'TestTakers' : 'Number of Students',
                               'Total' : ' Avg SAT Score'}, inplace=True)

# %%
act_2019.rename(columns = {'Composite' : 'Avg ACT Score'}, inplace=True)

# %%
sat_2019.rename(columns = {'Participation Rate' : 'Participation', 
                           'Total' : 'Avg SAT Score'}, inplace=True)

# %%
sat_by_major.head()
# Out:
#                                       Intended Major  Number of Students  \
# 0  Agriculture, AgricultureOperations, and Relate...             24913.0
# 1                  Architecture and Related Services             28988.0
# 2         Area, Ethnic, Cultural, and Gender Studies              2629.0
# 3                 Biological and Biomedical Sciences            155834.0
# 4  Business, Management, Marketing, and Related S...            221523.0
#
#    Percent   Avg SAT Score
# 0     0.01             977
# 1     0.02            1047
# 2     0.00            1040
# 3     0.08            1139
# 4     0.12            1072

# %%
# Match the rows between the intended majors for ACT and SAT

# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reindex.html
sat_by_major = sat_by_major.reindex([0, 1, 2, 35, 4, 5, 30, 6, 8, 9, 10, 11, 14, 26, 7, 3, 32])        
sat_by_major = sat_by_major.reset_index()
sat_by_major = sat_by_major.drop(columns = 'index')

# %%
print(sat_by_major)
# Out:
#                                        Intended Major  Number of Students  \
# 0   Agriculture, AgricultureOperations, and Relate...             24913.0
# 1                   Architecture and Related Services             28988.0
# 2          Area, Ethnic, Cultural, and Gender Studies              2629.0
# 3                 Visual and Performing Arts, General            130642.0
# 4   Business, Management, Marketing, and Related S...            221523.0
# 5     Communication, Journalism, and Related Programs             36332.0
# 6   Public Administration and Social Service Profe...              7852.0
# 7   Computer and Information Sciences and Support ...             79736.0
# 8                                           Education             71882.0
# 9                                         Engineering            194127.0
# 10               Engineering Technologies/Technicians             33595.0
# 11            English Language and Literature/Letters             16233.0
# ...

# %%
# Delete unnecessary rows
act_by_major.drop([12,18,19],axis=0,inplace=True)
act_by_major = act_by_major.reset_index()
act_by_major = act_by_major.drop(columns = 'index')

# %%
print(act_by_major)
# Out:
#                                   Intended Major  Number of Students  Percent  \
# 0   Agriculture & Natural Resources Conservation               21781     0.01
# 1                                   Architecture               15422     0.01
# 2      Area, Ethnic, & Multidisciplinary Studies                1761     0.00
# 3                      Arts: Visual & Performing               67693     0.04
# 4                                       Business              125457     0.08
# 5                                 Communications               18532     0.01
# 6         Community, Family, & Personal Services               26618     0.02
# 7                 Computer Science & Mathematics               46344     0.03
# 8                                      Education               49559     0.03
# 9                                    Engineering              104204     0.06
# 10             Engineering Technology & Drafting               16846     0.01
# ...

# %%
# Change values of all within column so we can merge
sat_by_major['Intended Major'] = act_by_major['Intended Major']
print(sat_by_major)
# Out:
#                                   Intended Major  Number of Students  Percent  \
# 0   Agriculture & Natural Resources Conservation             24913.0     0.01
# 1                                   Architecture             28988.0     0.02
# 2      Area, Ethnic, & Multidisciplinary Studies              2629.0     0.00
# 3                      Arts: Visual & Performing            130642.0     0.07
# 4                                       Business            221523.0     0.12
# 5                                 Communications             36332.0     0.02
# 6         Community, Family, & Personal Services              7852.0     0.00
# 7                 Computer Science & Mathematics             79736.0     0.04
# 8                                      Education             71882.0     0.04
# 9                                    Engineering            194127.0     0.11
# 10             Engineering Technology & Drafting             33595.0     0.02
# ...

# %%
# Merge dataframes that can be merged

intended_major = pd.merge(left = act_by_major, right = sat_by_major, left_on = 'Intended Major', right_on = 'Intended Major')

intended_major.head()
# Out:
#                                  Intended Major  Number of Students_x  \
# 0  Agriculture & Natural Resources Conservation                 21781
# 1                                  Architecture                 15422
# 2     Area, Ethnic, & Multidisciplinary Studies                  1761
# 3                     Arts: Visual & Performing                 67693
# 4                                      Business                125457
#
#    Percent_x  Avg ACT Score  Number of Students_y  Percent_y   Avg SAT Score
# 0       0.01           19.9               24913.0       0.01             977
# 1       0.01           21.1               28988.0       0.02            1047
# 2       0.00           21.6                2629.0       0.00            1040
# 3       0.04           20.7              130642.0       0.07            1045
# 4       0.08           21.5              221523.0       0.12            1072

# %%
# Creating a new dataframe that includes a column for Average ACT Score Scaled to SAT Score format.
# Used https://www.princetonreview.com/college-advice/act-to-sat-conversion to calculate by hand, since there is not a fixed ratio/equation.

intended_major_2 = intended_major.copy()
scaled_scores = [1020, 1062, 1077, 1038, 1075, 1098, 937, 1175, 1098, 1160, 1020, 1158, 1074, 1079, 902, 1171, 1106]

# Set new column to scaled score list
intended_major_2['Avg ACT Score Scaled'] = scaled_scores

# %%
intended_major_2.head()
# Out:
#                                  Intended Major  Number of Students_x  \
# 0  Agriculture & Natural Resources Conservation                 21781
# 1                                  Architecture                 15422
# 2     Area, Ethnic, & Multidisciplinary Studies                  1761
# 3                     Arts: Visual & Performing                 67693
# 4                                      Business                125457
#
#    Percent_x  Avg ACT Score  Number of Students_y  Percent_y   Avg SAT Score  \
# 0       0.01           19.9               24913.0       0.01             977
# 1       0.01           21.1               28988.0       0.02            1047
# 2       0.00           21.6                2629.0       0.00            1040
# 3       0.04           20.7              130642.0       0.07            1045
# 4       0.08           21.5              221523.0       0.12            1072
#
#    Avg ACT Score Scaled
# 0                  1020
# 1                  1062
# ...

# %%
state = pd.merge(left = act_2019, right = sat_2019, on = 'State')

state.head()
# Out:
#         State  Participation_x  Avg ACT Score  Participation_y  Avg SAT Score
# 0     Alabama             1.00           18.9             0.07           1143
# 1      Alaska             0.38           20.1             0.41           1097
# 2     Arizona             0.73           19.0             0.31           1134
# 3    Arkansas             1.00           19.3             0.06           1141
# 4  California             0.23           22.6             0.63           1065

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|<center>sat_2019/act_2019</center>|The name of the state for each data point|
# |participation|float|<center>sat_2019/act_2019<center>|The participation rate of students per given state|
# |Avg SAT Score|float|<center>*All Datasets*<center>|The average SAT score per state or intended major|
# |Avg ACT Score|float|<center>*All Datasets*<center>|The average ACT score per state or intended major|
# |Avg ACT Score Scaled|float|<center>act_2020_by_intended_college<center>|The average ACT score per state or intended major scaled to match the SAT scoring system|
# |Intended Major|object|sat_2019_by_intended_college/act_2020_by_intended_college|Selection of preferred major by student taking exam|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
intended_major_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 16
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Intended Major        17 non-null     object
#  1   Number of Students_x  17 non-null     int64
#  2   Percent_x             17 non-null     float64
#  3   Avg ACT Score         17 non-null     float64
#  4   Number of Students_y  17 non-null     float64
#  5   Percent_y             17 non-null     float64
#  6    Avg SAT Score        17 non-null     int64
#  7   Avg ACT Score Scaled  17 non-null     int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 1.2+ KB

# %%
intended_major_2.describe()
# Out:
#        Number of Students_x  Percent_x  Avg ACT Score  Number of Students_y  \
# count             17.000000  17.000000      17.000000             17.000000
# mean           54948.941176   0.033529      21.429412          80855.823529
# std            57364.881323   0.034810       2.095461          94685.021252
# min             1761.000000   0.000000      17.100000           2500.000000
# 25%            16846.000000   0.010000      20.400000          16233.000000
# 50%            26618.000000   0.020000      21.500000          33595.000000
# 75%            92008.000000   0.060000      22.300000         130642.000000
# max           218316.000000   0.130000      24.600000         331026.000000
#
#        Percent_y   Avg SAT Score  Avg ACT Score Scaled
# count  17.000000       17.000000             17.000000
# mean    0.043529     1065.764706           1073.529412
# std     0.051834       67.197963             75.785155
# min     0.000000      919.000000            902.000000
# ...

# %%
state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State            51 non-null     object
#  1   Participation_x  51 non-null     float64
#  2   Avg ACT Score    51 non-null     float64
#  3   Participation_y  51 non-null     float64
#  4   Avg SAT Score    51 non-null     int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 2.4+ KB

# %%
state.describe()
# Out:
#        Participation_x  Avg ACT Score  Participation_y  Avg SAT Score
# count        51.000000      51.000000        51.000000      51.000000
# mean          0.586667      21.464706         0.490588    1113.078431
# std           0.345159       2.194523         0.387476      97.197910
# min           0.060000      17.900000         0.020000     943.000000
# 25%           0.245000      19.800000         0.055000    1038.000000
# 50%           0.540000      21.100000         0.540000    1097.000000
# 75%           1.000000      23.700000         0.820000    1210.000000
# max           1.000000      25.500000         1.000000    1284.000000

# %%
sd = {i: find_std(state[i]) for i in state.columns if state[i].dtype == float or state[i].dtype == 'int64'}
sd
# Out:
# {'Participation_x': 29.368421438303045,
#  'Avg ACT Score': 15.402453031911206,
#  'Participation_y': 29.451600215403946,
#  'Avg SAT Score': 1087.1780822947399}

# %%
sd2 = {i: find_std(intended_major_2[i]) for i in intended_major_2.columns if intended_major_2[i].dtype == float or intended_major_2[i].dtype == 'int64'}
sd2
# Out:
# {'Number of Students_x': 54939.94139489091,
#  'Percent_x': 10.217514120846056,
#  'Avg ACT Score': 13.360025329938896,
#  'Number of Students_y': 80846.8236778406,
#  'Percent_y': 10.208739657662148,
#  ' Avg SAT Score': 1056.7760612346476,
#  'Avg ACT Score Scaled': 1064.5406842916389}

# %%
# Let's find the top 10 scoring intended majors for ACT (scaled)

intended_major_2.sort_values('Avg ACT Score Scaled', ascending = False).head()
# Out:
#                      Intended Major  Number of Students_x  Percent_x  \
# 7    Computer Science & Mathematics                 46344       0.03
# 15  Sciences: Biological & Physical                 97984       0.06
# 9                       Engineering                104204       0.06
# 11      English & Foreign Languages                 10895       0.01
# 16            Social Sciences & Law                 92008       0.06
#
#     Avg ACT Score  Number of Students_y  Percent_y   Avg SAT Score  \
# 7            24.6               79736.0       0.04            1156
# 15           24.4              155834.0       0.08            1139
# 9            24.0              194127.0       0.11            1139
# 11           23.9               16233.0       0.01            1119
# 16           22.3               33356.0       0.02            1164
#
#     Avg ACT Score Scaled
# 7                   1175
# 15                  1171
# 9                   1160
# 11                  1158
# ...

# %%
# Now, the lowest scoring majors for ACT (scaled)

intended_major_2.sort_values('Avg ACT Score Scaled').head()
# Out:
#                                   Intended Major  Number of Students_x  \
# 14            Repair, Production, & Construction                 16860
# 6         Community, Family, & Personal Services                 26618
# 0   Agriculture & Natural Resources Conservation                 21781
# 10             Engineering Technology & Drafting                 16846
# 3                      Arts: Visual & Performing                 67693
#
#     Percent_x  Avg ACT Score  Number of Students_y  Percent_y   Avg SAT Score  \
# 14       0.01           17.1                2500.0       0.00             919
# 6        0.02           17.9                7852.0       0.00            1001
# 0        0.01           19.9               24913.0       0.01             977
# 10       0.01           19.9               33595.0       0.02            1041
# 3        0.04           20.7              130642.0       0.07            1045
#
#     Avg ACT Score Scaled
# 14                   902
# ...

# %%
# Let's find the top 10 scoring intended majors for SAT

intended_major_2.sort_values(' Avg SAT Score', ascending = False).head()
# Out:
#                       Intended Major  Number of Students_x  Percent_x  \
# 16             Social Sciences & Law                 92008       0.06
# 7     Computer Science & Mathematics                 46344       0.03
# 15   Sciences: Biological & Physical                 97984       0.06
# 9                        Engineering                104204       0.06
# 13  Philosophy, Religion, & Theology                  3852       0.00
#
#     Avg ACT Score  Number of Students_y  Percent_y   Avg SAT Score  \
# 16           22.3               33356.0       0.02            1164
# 7            24.6               79736.0       0.04            1156
# 15           24.4              155834.0       0.08            1139
# 9            24.0              194127.0       0.11            1139
# 13           21.7                3381.0       0.00            1120
#
#     Avg ACT Score Scaled
# 16                  1106
# 7                   1175
# 15                  1171
# 9                   1160
# ...

# %%
# Now, the lowest scoring majors for the SAT

intended_major_2.sort_values(' Avg SAT Score').head()
# Out:
#                                   Intended Major  Number of Students_x  \
# 14            Repair, Production, & Construction                 16860
# 0   Agriculture & Natural Resources Conservation                 21781
# 6         Community, Family, & Personal Services                 26618
# 8                                      Education                 49559
# 2      Area, Ethnic, & Multidisciplinary Studies                  1761
#
#     Percent_x  Avg ACT Score  Number of Students_y  Percent_y   Avg SAT Score  \
# 14       0.01           17.1                2500.0       0.00             919
# 0        0.01           19.9               24913.0       0.01             977
# 6        0.02           17.9                7852.0       0.00            1001
# 8        0.03           20.4               71882.0       0.04            1022
# 2        0.00           21.6                2629.0       0.00            1040
#
#     Avg ACT Score Scaled
# 14                   902
# ...

# %% [markdown]
# **Findings**
#
# It seems that between the SAT and ACT, the top scoring group is different, with Computer Science and Mathematics
# doing the best for the ACT, and Social Sciences doing the best for the SAT. The second through fourth highest scoring groups
# are relatively the same, suggesting that those groups do equally well between examinations.
#
# The lowest scoring groups do not have that much variation, with Repair/Construction and Agriculture scoring the lowest. For the ACT, it
# is interesting to see that Engineering drafting was one of the lowest scoring groups.

# %%
# Let's find the highest participation for ACT in states

state.sort_values('Participation_x', ascending = False).head()
# Out:
#         State  Participation_x  Avg ACT Score  Participation_y  Avg SAT Score
# 0     Alabama              1.0           18.9             0.07           1143
# 17   Kentucky              1.0           19.8             0.04           1232
# 49  Wisconsin              1.0           20.3             0.03           1283
# 44       Utah              1.0           20.3             0.04           1230
# 42  Tennessee              1.0           19.4             0.07           1220

# %%
# Let's find the highest participation for SAT in states

state.sort_values('Participation_y', ascending = False).head()
# Out:
#            State  Participation_x  Avg ACT Score  Participation_y  \
# 39  Rhode Island             0.12           24.7              1.0
# 13      Illinois             0.35           24.3              1.0
# 22      Michigan             0.19           24.4              1.0
# 5       Colorado             0.27           23.8              1.0
# 6    Connecticut             0.22           25.5              1.0
#
#     Avg SAT Score
# 39            995
# 13           1013
# 22           1003
# 5            1024
# 6            1046

# %%
state.sort_values('Avg ACT Score', ascending = False).head()
# Out:
#             State  Participation_x  Avg ACT Score  Participation_y  \
# 21  Massachusetts             0.21           25.5             0.81
# 6     Connecticut             0.22           25.5             1.00
# 29  New Hampshire             0.14           25.0             0.95
# 39   Rhode Island             0.12           24.7             1.00
# 32       New York             0.22           24.5             0.79
#
#     Avg SAT Score
# 21           1120
# 6            1046
# 29           1059
# 39            995
# 32           1064

# %%
state.sort_values('Avg SAT Score', ascending = False).head()
# Out:
#            State  Participation_x  Avg ACT Score  Participation_y  \
# 23     Minnesota             0.95           21.4             0.04
# 49     Wisconsin             1.00           20.3             0.03
# 41  South Dakota             0.75           21.6             0.03
# 34  North Dakota             0.96           19.9             0.02
# 27      Nebraska             1.00           20.0             0.03
#
#     Avg SAT Score
# 23           1284
# 49           1283
# 41           1268
# 34           1263
# 27           1260

# %%
state.sort_values('Avg ACT Score').head()
# Out:
#              State  Participation_x  Avg ACT Score  Participation_y  \
# 28          Nevada             1.00           17.9             0.20
# 24     Mississippi             1.00           18.4             0.03
# 40  South Carolina             0.78           18.8             0.68
# 18       Louisiana             1.00           18.8             0.05
# 0          Alabama             1.00           18.9             0.07
#
#     Avg SAT Score
# 28           1156
# 24           1237
# 40           1030
# 18           1200
# 0            1143

# %%
state.sort_values('Avg SAT Score').head()
# Out:
#                    State  Participation_x  Avg ACT Score  Participation_y  \
# 48         West Virginia             0.49           20.8             0.99
# 36              Oklahoma             1.00           18.9             0.22
# 8   District of Columbia             0.32           23.5             0.94
# 7               Delaware             0.13           24.1             1.00
# 12                 Idaho             0.31           22.5             1.00
#
#     Avg SAT Score
# 48            943
# 36            963
# 8             975
# 7             985
# 12            993

# %% [markdown]
# **Findings**
#
# It seems that mostly Central U.S. states and the Midwest favor the ACT, whereas the coasts favor the SAT.
#
# The highest scoring states tend to be coastal states as well, and lowest scoring the middle America.

# %% [markdown]
# ## Visualize the Data

# %%
# Create a bar chart for Average SAT Score per Intended Major

plt.figure(figsize=(12,12))
plt.bar(intended_major['Intended Major'],
        intended_major[' Avg SAT Score'])

# add a title
plt.title('Average SAT Score for Intended Major', size = 20)

# rotate x-ticks
plt.xticks(rotation = 90)

# add axis labels
plt.ylabel('Average SAT Score', size = 12)
plt.xlabel('Intended Major', size = 12);

plt.tight_layout()

# %%
# Create a bar chart for Average ACT Score, Scaled to SAT Score format
plt.figure(figsize=(12,12))

# horizontal bar chart
plt.bar(intended_major_2['Intended Major'],
        intended_major_2['Avg ACT Score Scaled'])

# add a title
plt.title('Average ACT Score (Scaled) for Intended Major', size = 20)

# rotate x-ticks
plt.xticks(rotation = 90)

# add axis labels
plt.ylabel('Average ACT Score (Scaled)', size = 12)
plt.xlabel('Intended Major', size = 12);

plt.tight_layout()

# %%
# It's hard to visualize differences between two bar graphs, so let's create a stacked bar chart

# %%
fig, ax = plt.subplots(figsize = (12, 12))

sat_plot = ax.bar(x = intended_major['Intended Major'], height = intended_major[' Avg SAT Score'], color = 'blue', label = 'SAT')


ax2 = ax.twinx()
act_plot = ax2.bar(x = intended_major['Intended Major'], height = intended_major_2['Avg ACT Score'], color = 'red', label = 'ACT')


ax2.set(yticks = range(0,38,4), title = 'Comparison Between SAT and ACT Scores, per Intended Major', xlabel = 'Intended Major', ylabel = 'ACT Score')

ax.set(yticks = range(0, 1601, 200), ylabel = 'SAT Score')
for tick in ax.get_xticklabels():
    tick.set_rotation(90)

ax.legend(loc='upper right')
ax2.legend(loc='upper left')

plt.show();

# This chart seems to show that EVERYONE, regardless of area of aptitude, does better at the ACT than the SAT, 
# but fails to recognize the difference in percentile scoring between the two exams

# %%
fig, ax = plt.subplots(figsize = (12, 12))

act_plot = ax.bar(x = intended_major['Intended Major'], height = intended_major_2['Avg ACT Score Scaled'], color = 'red', label = 'ACT')

ax2 = ax.twinx()

sat_plot = ax2.bar(x = intended_major['Intended Major'], height = intended_major[' Avg SAT Score'], color = 'blue', label = 'SAT')


ax.set(yticks = range(0, 1601, 200), title = 'Comparison Between SAT and ACT Scores, per Intended Major, SAT Scale', xlabel = 'Intended Major', ylabel = 'Score (SAT Scale)')

ax2.set(yticks = range(0, 1601, 200))
for tick in ax.get_xticklabels():
    tick.set_rotation(90)

ax.legend(loc='upper left')
ax2.legend(loc='upper right')


plt.show();
fig.savefig('../imgs/stacked_bar_major.png', format = 'png', bbox_inches='tight', pad_inches=0)

# This chart is the same as above, but scaling all scores to the SAT score scale.
# This yields much more meaningful comparisons

# %%
sat_2019.head()
# Out:
#         State  Participation  Avg SAT Score
# 0     Alabama           0.07           1143
# 1      Alaska           0.41           1097
# 2     Arizona           0.31           1134
# 3    Arkansas           0.06           1141
# 4  California           0.63           1065

# %%
plt.figure(figsize=(12,5))


plt.scatter(sat_2019['Participation'],
            sat_2019['Avg SAT Score'])

# Creating a trendline, found on https://www.statology.org/matplotlib-trendline/
x = sat_2019['Participation']
y = sat_2019['Avg SAT Score']
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), color = 'red')


plt.title('States with Less SAT Test-Takers Tend to Score Higher')


plt.xlabel('Participation Rate for SAT')
plt.ylabel('Average SAT Score');

plt.savefig('../imgs/linegraph_sat.png', dpi = 300, format = 'png')

# %%
plt.figure(figsize=(12,5))

plt.scatter(act_2019['Participation'],
            act_2019['Avg ACT Score'])

# Creating a trendline, found on https://www.statology.org/matplotlib-trendline/
x = act_2019['Participation']
y = act_2019['Avg ACT Score']
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), color = 'red')


plt.title('States with Less ACT Test-Takers Also Tend to Score Higher')



plt.xlabel('Participation Rate for ACT')
plt.ylabel('Average ACT Score');

plt.savefig('../imgs/linegraph_act.png', dpi = 300, format = 'png')

# %%
intended_major_2.head()
# Out:
#                                  Intended Major  Number of Students_x  \
# 0  Agriculture & Natural Resources Conservation                 21781
# 1                                  Architecture                 15422
# 2     Area, Ethnic, & Multidisciplinary Studies                  1761
# 3                     Arts: Visual & Performing                 67693
# 4                                      Business                125457
#
#    Percent_x  Avg ACT Score  Number of Students_y  Percent_y   Avg SAT Score  \
# 0       0.01           19.9               24913.0       0.01             977
# 1       0.01           21.1               28988.0       0.02            1047
# 2       0.00           21.6                2629.0       0.00            1040
# 3       0.04           20.7              130642.0       0.07            1045
# 4       0.08           21.5              221523.0       0.12            1072
#
#    Avg ACT Score Scaled
# 0                  1020
# 1                  1062
# ...

# %%
df = intended_major_2.iloc[:, [0, 1, 4, 6, 7]]
df.rename(columns = {'Number of Students_x':'Number of ACT Takers', 'Number of Students_y':'Number of SAT Takers'}, inplace = True)
df.head()
# Out:
# C:\Users\Jason Lu\AppData\Local\Temp\ipykernel_21344\2558288978.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'Number of Students_x':'Number of ACT Takers', 'Number of Students_y':'Number of SAT Takers'}, inplace = True)
#                                  Intended Major  Number of ACT Takers  \
# 0  Agriculture & Natural Resources Conservation                 21781
# 1                                  Architecture                 15422
# 2     Area, Ethnic, & Multidisciplinary Studies                  1761
# 3                     Arts: Visual & Performing                 67693
# 4                                      Business                125457
#
#    Number of SAT Takers   Avg SAT Score  Avg ACT Score Scaled
# ...

# %%
plt.figure(figsize = (16, 9))

corr = df.corr()

# mask upper triangle to be white
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# Plot our correlation heatmap
sns.heatmap(corr,
            mask = mask,
           square = True,
           cmap = 'coolwarm',
           annot = True);    # annot = True puts the correlation coefficient in the square

plt.title('Correlation Between Number of Participants and Average Test Scores', fontsize = 16);
# Out:
# C:\Users\Jason Lu\AppData\Local\Temp\ipykernel_21344\608271163.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# The data highlights that students with a strong foundation in the STEM field do better on the ACT than the SAT. Conversely, students with a background and aptitude for humanities do better on the SAT. However, there are a few groups that score equally high on both exams, which may suggest that the difference between the exams is not a major contribution to benefitting certain aptitudes.
#
# Additionally, the average score of tests correlate negatively with the popularity of the test within certain states. This is understood as that students who choose the less popular test within a state have a preference for it, whether it be for aptitude or otherwise. These students are likely to score better because they are likely more informed about the exam, having deliberately chosen it to suit their skills.
#
# Further analysis of different data over multiple years is required, especially data revolving around individual preferences rather than assumed aptitudes.
